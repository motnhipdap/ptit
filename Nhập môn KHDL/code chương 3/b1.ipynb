# %%
years = [2010, 2012, 2014, 2016, 2018, 2020, 2022] 
population = [1.2, 5.35, 1.5, 1.65, 1.8, 1.95, 2.1]

height = [150, 155, 160, 165, 170, 172, 175, 178, 180, 185]  
weight = [45, 48, 52, 56, 60, 63, 65, 70, 72, 78]

# %%
import matplotlib.pyplot as plt


plt.xlabel('Year')
plt.ylabel('population')

plt.title('tang truong dan so')

plt.plot(years,population,marker = 'o')
