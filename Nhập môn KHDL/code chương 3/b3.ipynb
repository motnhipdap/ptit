# %%
from random import randint
import matplotlib.pyplot as plt

a = []

for i in range(50):
    a.append(randint(40,100))

plt.hist(a,color = 'green',edgecolor = 'black')
# Out:
# (array([5., 5., 9., 1., 3., 7., 3., 6., 3., 8.]),
#  array([41. , 46.5, 52. , 57.5, 63. , 68.5, 74. , 79.5, 85. , 90.5, 96. ]),
#  <BarContainer object of 10 artists>)
